# %% [markdown]
# <a href="https://colab.research.google.com/github/pulkitshringi/Colab/blob/main/pookie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%html
# <h3>Pookie here</h3>
# Out:
# <h3>Pookie here</h3>

# %%
from matplotlib import pyplot as plt

x_values = [1, 2, 3, 4]
y_values = [5, 4, 6, 2]
plt.plot(x_values, y_values)
plt.title("Pooki graph")
plt.xlabel("Pookie X")
plt.ylabel("Pookie Y")
plt.show()
